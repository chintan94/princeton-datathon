# %%
import pandas as pd

# %%
service_reqs = pd.read_csv("311_service_requests.csv")
inspections = pd.read_csv("food_establishment_inspections_city.csv")
food_venues = pd.read_csv("food_venues.csv")
geographics = pd.read_csv("geographic.csv")
# Out:
# /Users/chintandoshi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
inspections.head()
# Out:
#                                name        borough        street_name  \
# 0   THE OLD SIAM RESTAURANT AND BAR         QUEENS          AUSTIN ST
# 1           DANNY'S PIZZERIA & CAFE       BROOKLYN    BUSHWICK AVENUE
# 2                          CLUB 101      MANHATTAN        PARK AVENUE
# 3                 PRONTO RESTAURANT  STATEN ISLAND    RICHMOND AVENUE
# 4  GOOD SHEPHERD SERVICES BRONX DJJ          BRONX  UNIVERSITY AVENUE
#
#    zipcode       phone        cuisine date_inspection  \
# 0  11375.0  7185446444           Thai        10/20/15
# 1  11206.0  7183811669  Pizza/Italian         7/12/16
# 2  10178.0  2128180263       American         5/10/16
# 3  10312.0  7183562442  Pizza/Italian         11/2/16
# 4  10453.0  7185610251       American          2/8/17
#
#                                             action violation_code  \
# 0  Violations were cited in the following area(s).            06C
# 1  Violations were cited in the following area(s).            10H
# ...

# %%
inspections["zipcode"].value_counts()
# Out:
# 10003.0    9810
# 10019.0    9122
# 10036.0    8283
# 10013.0    8098
# 10002.0    7299
# 10016.0    6876
# 10001.0    6706
# 10022.0    6307
# 11354.0    6119
# 11220.0    6068
# 10011.0    6051
# 10012.0    5791
# 11372.0    5664
# 11201.0    5526
# 10014.0    5471
# 10017.0    5219
# 11211.0    5020
# 11215.0    4942
# 10018.0    4777
# 10009.0    4526
# 11368.0    4247
# 11101.0    4002
# 11209.0    3954
# 10010.0    3647
# 11217.0    3646
# 10025.0    3639
# 11385.0    3635
# 11355.0    3503
# 11373.0    3492
# 11238.0    3451
#            ...
# 10167.0      30
# 11001.0      30
# 10178.0      29
# 10000.0      28
# 10154.0      26
# 10174.0      22
# 10115.0      21
# 10165.0      21
# 10069.0      19
# 10168.0      18
# 10106.0      16
# 11371.0      14
# 11242.0      14
# 10176.0      14
# 10055.0      11
# 11241.0      10
# 10171.0      10
# 10123.0      10
# 10173.0       8
# 10179.0       8
# 10041.0       8
# 10153.0       7
# 10107.0       6
# 10177.0       6
# ...

# %%
service_reqs.groupby(by="complaint_type",as_index=False).agg({"unique_key":pd.Series.nunique}).sort_values(by="unique_key")
# Out:
#                    complaint_type  unique_key
# 36                           MOLD           1
# 3     Animal unsanitary condition           1
# 10                   CFC Recovery           1
# 9   Biking/Rollerblading Off Path           1
# 28              Health and Safety           1
# 35        Killing/Trapping Pigeon           2
# 30         Homebound Evacuation 4           2
# 12       DOHMH Literature Request           4
# 18              Employee Behavior           4
# 22               General Question           4
# 25           Hazardous Conditions           5
# 29          Healthcare Facilities           6
# 34               Injured Wildlife           6
# 24                    Grass/Weeds           8
# 13       DORIS Literature Request          10
# 23          Graffiti or Vandalism          10
# 32        Illegal Pet - Sold/Kept          12
# 21              Garbage or Litter          14
# 8                    Baby Formula          16
# ...
